# %%
import pandas as pd
import matplotlib
def unpack_and_graph(data, threshold_percent):
    count_total = 0
    skill_counts = dict()
    skill_set = set()
    k_title = list(data.keys())
    title = k_title[0]
    k_geo = list(data[title].keys())
    geo = k_geo[0]
    salaries = [salary for salary in data[title][geo].keys()]
    zip_codes = [zip for zip in data[title][geo][salaries[0]]]
    for zip in zip_codes:
      skill_dict = data[title][geo][salaries[0]][zip] 
    for skill in skill_dict.keys():
      skill_set.add(skill)
    for skill in skill_set:
      skill_counts.setdefault(skill, 0)
      skill_counts[skill]+= skill_dict[skill]
    count_total = sum(list(skill_counts.values()))
    skill_av_dict = dict()
    for skill in skill_set:
      skill_av_dict.setdefault(skill, 0)
    for skill, value in skill_counts.items():
      average = value / count_total * 100
      skill_av_dict[skill] = average
    s = pd.Series(skill_av_dict)
    df = pd.DataFrame({'demand_percent':s})
    df.index.name = f'{title} in {geo}'
    df.drop(df[df.demand_percent <= threshold_percent].index, inplace=True)
    df.sort_values('demand_percent',ascending=False, inplace=True)
    print(df)
    df.demand_percent.plot(kind='bar')

# %% [markdown]
# # San Fracisco Data Science Engineer Skill Demand
# * "Acceptance" typically refers to "acceptance testing" in software qa
# * "Case" typically refers to "test case" in software qa
# The program does not parse on phrases and therefore it is unknown if the results reflect the typical usage of these two skill words

# %%
data = {'data science engineer': {'San Francisco Bay Area': {'150000': {'95032': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '95054': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94010': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94536': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94539': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94402': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94404': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94403': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94538': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94560': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94065': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94063': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94027': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94002': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94070': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '95134': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '95002': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94062': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94089': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94301': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94025': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94303': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '95035': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '95140': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94061': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94043': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94304': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94305': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94035': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94306': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94028': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94040': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94022': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94085': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94086': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94024': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94087': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}}, '100000': {'95032': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '95054': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94010': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94536': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94539': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94402': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94404': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94403': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94538': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94560': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94065': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94063': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94027': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94002': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94070': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '95134': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '95002': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94062': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94089': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94301': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94025': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94303': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '95035': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '95140': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94061': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94043': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94304': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94305': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94035': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94306': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94028': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94040': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94022': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94085': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94086': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94024': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94087': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}}, '50000': {'95032': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '95054': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94010': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94536': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94539': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94402': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94404': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94403': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94538': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94560': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94065': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94063': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94027': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94002': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94070': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '95134': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '95002': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94062': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94089': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94301': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94025': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94303': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '95035': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '95140': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94061': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94043': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94304': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94305': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94035': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94306': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94028': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94040': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94022': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94085': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94086': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94024': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}, '94087': {'python': 1, 'c++': 1, 'java': 1, 'ruby': 1, 'Machine': 1, 'learning': 1, 'react': 1, 'hadoop': 1, 'backend': 2, 'mysql': 1, 'mobile': 11, 'aws': 1, 'amazon': 1, 'google': 1, 'rest': 1, 'network': 11, 'node.js': 1, 'go': 1, 'database': 2, 'healthcare': 1, 'case': 5, 'integration': 4, 'api': 9, 'telecommunications': 5, 'marketing': 4, 'acceptance': 5}}}}}
threshold_percent = 5.0
unpack_and_graph(data, threshold_percent)
# Out:
#                                                  demand_percent
# data science engineer in San Francisco Bay Area
# network                                               14.864865
# mobile                                                14.864865
# api                                                   12.162162
# case                                                   6.756757
# acceptance                                             6.756757
# telecommunications                                     6.756757
# marketing                                              5.405405
# integration                                            5.405405

# %% [markdown]
# # Boston Data Science Engineer Skill Demand
# * "Acceptance" typically refers to "acceptance testing" in software qa
# * "Case" typically refers to "test case" in software qa
# The program does not parse on phrases and therefore it is unknown if the results reflect the typical usage of these two skill words
# It is most likely that the two represent a phrase and can be considered one skill at around 4%
#
# * "Reduce" typically refers to "Map Reduce"

# %%
data ={'data science engineer': {'Sufolk County, Boston MA': {'150000': {'2101': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2102': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2103': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2104': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2105': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2106': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2107': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2108': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2109': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2110': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2111': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2112': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2113': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2114': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2115': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2116': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2117': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2118': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2119': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2120': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2121': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2122': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2123': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2124': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2125': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2126': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2127': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2128': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2129': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2130': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2131': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2132': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2133': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2134': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2135': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2136': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2137': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}}, '100000': {'2101': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2102': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2103': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2104': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2105': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2106': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2107': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2108': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2109': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2110': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2111': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2112': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2113': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2114': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2115': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2116': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2117': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2118': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2119': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2120': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2121': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2122': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2123': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2124': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2125': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2126': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2127': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2128': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2129': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2130': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2131': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2132': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2133': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2134': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2135': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2136': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2137': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}}, '50000': {'2101': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2102': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2103': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2104': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2105': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2106': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2107': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2108': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2109': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2110': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2111': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2112': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2113': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2114': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2115': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2116': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2117': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2118': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2119': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2120': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2121': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2122': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2123': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2124': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2125': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2126': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2127': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2128': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2129': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2130': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2131': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2132': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2133': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2134': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2135': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2136': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}, '2137': {'python': 7, 'java': 15, 'ruby': 4, 'javascript': 14, 'big': 6, 'php': 3, 'Confluence': 1, 'integration': 23, 'hadoop': 2, 'api': 41, 'mysql': 2, 'oracle': 2, 'mobile': 60, 'ios': 2, 'telecommunications': 10, 'aws': 5, 'kubernetes': 2, 'network': 60, 'ci': 2, 'cd': 1, 'marketing': 33, 'linux': 7, 'ui': 3, 'database': 10, 'scala': 2, 'sas': 1, 'cucumber': 2, 'amazon': 7, 'google': 16, 'go': 1, 'Machine': 2, 'react': 3, 'nosql': 3, 'rdbms': 1, 'networking': 1, 'node.js': 5, 'git': 3, 'banking': 2, 'case': 20, 'acceptance': 9, 'learning': 5, 'c#': 7, 'plan': 4, 'functional': 1, 'spark': 1, 'sql': 4, 'docker': 3, 'Excel': 2, 'windows': 3, 'reduce': 11, 'statistical': 11, 'performance': 13, 'azure': 3, 'Elastic': 1, 'frontend': 4, 'backend': 8, 'cassandra': 1, '.net': 5, 'RESTful': 2, 'r': 1, 'Solr': 1, 'load': 2, 'apis': 2, 'Typescript': 2, 'c++': 2, 'scripting': 1, 'saas': 1, 'iot': 1, 'ci/cd': 1, 'angular': 2, 'css': 4, 'html': 1, 'unix': 1, 'xml': 1, 'json': 1, 'github': 1, 'black': 1, 'android': 1}}}}}
threshold_percent = 2.0
unpack_and_graph(data, threshold_percent)
# Out:
#                                                    demand_percent
# data science engineer in Sufolk County, Boston MA
# network                                                 11.787819
# mobile                                                  11.787819
# api                                                      8.055010
# marketing                                                6.483301
# integration                                              4.518664
# case                                                     3.929273
# google                                                   3.143418
# java                                                     2.946955
# javascript                                               2.750491
# performance                                              2.554028
# statistical                                              2.161100
# reduce                                                   2.161100

# %% [markdown]
# # Phoenix Data Science Engineer Skill Demand
# * "Learning" typically refers to "machine learning"
# * "Machine" typically refers to "test case" in software qa
# The program does not parse on phrases and therefore it is unknown if the results reflect the typical usage of these two skill words.
# It is most likely that the two represent a phrase and can be considered one skill at around 8%

# %%
data = {'data science engineer': {'Phoenix, AZ': {'150000': {'85003': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85004': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85006': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85007': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85008': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85009': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85012': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85013': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85014': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85015': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85016': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85017': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85018': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85019': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85020': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85021': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85022': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85023': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85024': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85027': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85028': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85029': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85031': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85032': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85033': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85034': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85035': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85037': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85040': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85041': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85042': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85043': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85044': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85045': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85048': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85050': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85051': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85053': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85054': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85083': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85085': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85086': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85087': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85226': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}}, '100000': {'85003': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85004': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85006': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85007': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85008': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85009': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85012': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85013': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85014': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85015': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85016': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85017': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85018': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85019': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85020': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85021': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85022': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85023': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85024': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85027': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85028': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85029': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85031': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85032': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85033': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85034': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85035': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85037': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85040': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85041': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85042': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85043': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85044': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85045': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85048': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85050': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85051': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85053': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85054': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85083': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85085': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85086': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85087': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85226': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}}, '50000': {'85003': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85004': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85006': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85007': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85008': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85009': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85012': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85013': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85014': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85015': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85016': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85017': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85018': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85019': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85020': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85021': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85022': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85023': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85024': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85027': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85028': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85029': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85031': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85032': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85033': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85034': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85035': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85037': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85040': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85041': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85042': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85043': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85044': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85045': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85048': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85050': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85051': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85053': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85054': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85083': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85085': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85086': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85087': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}, '85226': {'python': 755, 'c++': 132, 'java': 286, 'Machine': 934, 'learning': 744, 'big': 781, 'statistical': 840, 'visualization': 486, 'ETL': 228, 'tableau': 132, 'pandas': 176, 'performance': 306, 'hadoop': 296, 'hive': 120, 'sql': 584, 'mobile': 218, 'aws': 229, 'azure': 143, 'docker': 300, 'storage': 176, 'network': 484, 'ci/cd': 132, 'ui': 49, 'git': 145, 'database': 346, 'r': 517, 'Statistics': 321, 'Economics': 132, 'marketing': 177, 'matlab': 88, 'javascript': 101, 'scala': 192, 'map': 129, 'scripts': 45, 'sas': 88, 'saas': 35, 'plan': 189, 'jira': 80, 'functional': 15, 'integration': 74, 'spark': 371, 'apis': 98, 'nosql': 3, 'hbase': 93, 'cassandra': 3, 'mongodb': 3, 'mysql': 88, 'oracle': 3, 'rdbms': 88, 'amazon': 173, 'google': 149, 'rest': 17, 'container': 88, 'networking': 136, 'PL/SQL': 12, 'node.js': 88, 'kafka': 89, 'go': 88, 'css': 6, 'linux': 102, 'Elastic': 127, 'github': 78, 'Mathematics': 88, 'NLP': 173, 'Bayesian': 220, 'scripting': 11, '.net': 15, 'angular': 10, 'api': 61, 'groovy': 14, 'RESTful': 47, 'case': 10, 'oozie': 1, 'warehouse': 4, 'unix': 4, 'Jenkins': 1}}}}}
threshold_percent = 4.0
unpack_and_graph(data, threshold_percent)
# Out:
#                                       demand_percent
# data science engineer in Phoenix, AZ
# Machine                                     6.784339
# statistical                                 6.101547
# big                                         5.672986
# python                                      5.484129
# learning                                    5.404228
# sql                                         4.242028

# %% [markdown]
# # Austin Data Science Skill Demand
# * "Learning" typically refers to "machine learning"
# * "Machine" typically refers to "test case" in software qa
# The program does not parse on phrases and therefore it is unknown if the results reflect the typical usage of these two skill words.
# It is most likely that the two represent a phrase and can be considered one skill at around 8%

# %%
data = {'data science engineer': {'Travis County, Austin TX': {'150000': {'78764': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78768': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78767': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78772': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78769': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78783': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78610': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78613': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78615': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78617': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78621': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '73301': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '73344': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78641': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78645': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78652': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78654': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78653': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78660': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78664': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78669': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78691': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78702': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78701': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78704': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78703': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78705': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78712': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78713': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78716': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78719': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78722': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78721': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78724': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78723': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78726': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78725': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78728': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78727': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78730': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78732': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78731': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78734': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78733': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78736': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78735': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78738': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78737': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78741': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78739': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78744': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78742': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78746': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78745': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78748': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78747': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78750': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78749': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78752': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78751': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78754': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78753': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78756': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78758': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78757': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78760': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78759': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}}, '100000': {'78764': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78768': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78767': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78772': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78769': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78783': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78610': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78613': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78615': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78617': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78621': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '73301': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '73344': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78641': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78645': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78652': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78654': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78653': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78660': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78664': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78669': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78691': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78702': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78701': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78704': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78703': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78705': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78712': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78713': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78716': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78719': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78722': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78721': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78724': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78723': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78726': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78725': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78728': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78727': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78730': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78732': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78731': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78734': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78733': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78736': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78735': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78738': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78737': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78741': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78739': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78744': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78742': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78746': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78745': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78748': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78747': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78750': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78749': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78752': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78751': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78754': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78753': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78756': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78758': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78757': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78760': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78759': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}}, '50000': {'78764': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78768': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78767': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78772': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78769': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78783': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78610': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78613': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78615': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78617': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78621': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '73301': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '73344': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78641': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78645': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78652': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78654': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78653': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78660': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78664': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78669': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78691': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78702': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78701': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78704': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78703': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78705': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78712': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78713': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78716': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78719': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78722': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78721': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78724': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78723': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78726': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78725': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78728': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78727': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78730': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78732': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78731': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78734': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78733': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78736': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78735': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78738': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78737': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78741': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78739': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78744': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78742': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78746': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78745': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78748': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78747': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78750': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78749': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78752': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78751': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78754': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78753': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78756': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78758': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78757': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78760': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}, '78759': {'python': 740, 'c++': 578, 'java': 39, 'perl': 390, 'Machine': 1215, 'learning': 1285, 'big': 574, 'statistical': 385, 'scripting': 275, 'react': 138, 'saas': 158, 'plan': 263, 'integration': 410, 'stress': 138, 'performance': 369, 'spark': 192, 'hive': 526, 'apis': 103, 'sql': 381, 'nosql': 16, 'cassandra': 129, 'aws': 243, 'azure': 272, 'google': 181, 'docker': 150, 'kubernetes': 150, 'networking': 69, 'kafka': 129, 'django': 138, 'healthcare': 272, 'banking': 138, 'r': 219, 'Statistics': 138, 'Mathematics': 169, 'scala': 142, 'visualizations': 22, 'visualization': 202, 'map': 127, 'reduce': 127, 'ETL': 258, 'c#': 134, 'functional': 293, 'load': 69, 'hadoop': 218, 'api': 112, 'mysql': 30, 'oracle': 112, 'rdbms': 30, 'mobile': 80, 'android': 134, 'ios': 340, 'telecommunications': 121, 'amazon': 134, 'rest': 92, 'storage': 77, 'network': 276, 'go': 71, 'Elastic': 67, 'database': 450, 'javascript': 36, 'junit': 36, 'case': 10, 'marketing': 43, 'MDM': 36, 'css': 72, 'html': 36, 'Economics': 10, 'scripts': 12, 'tableau': 12, 'splunk': 122, 'xml': 12, 'mongodb': 122, 'mssql': 12, 'linux': 16, 'git': 12, 'Excel': 12, 'firmware': 1, 'warehouse': 16, 'ruby': 4, 'black': 4}}}}}
threshold_percent = 3.0
unpack_and_graph(data, threshold_percent)
# Out:
#                                                    demand_percent
# data science engineer in Travis County, Austin TX
# learning                                                 8.609138
# Machine                                                  8.140158
# python                                                   4.957792
# c++                                                      3.872437
# big                                                      3.845638
# hive                                                     3.524052
# database                                                 3.014873

# %% [markdown]
# # San Francisco Software Quality Assurance
# * "Learning" typically refers to "Machine Learning"

# %%
data = {'software quality assurance engineer': {'San Francisco Bay Area': {'150000': {'95032': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '95054': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94010': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94536': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94539': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94402': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94404': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94403': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94538': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94560': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94065': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94063': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94027': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94002': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94070': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '95134': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '95002': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94062': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94089': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94301': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94025': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94303': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '95035': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '95140': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94061': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94043': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94304': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94305': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94035': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94306': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94028': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94040': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94022': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94085': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94086': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94024': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94087': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}}, '100000': {'95032': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '95054': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94010': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94536': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94539': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94402': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94404': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94403': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94538': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94560': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94065': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94063': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94027': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94002': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94070': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '95134': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '95002': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94062': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94089': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94301': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94025': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94303': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '95035': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '95140': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94061': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94043': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94304': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94305': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94035': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94306': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94028': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94040': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94022': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94085': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94086': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94024': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94087': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}}, '50000': {'95032': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '95054': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94010': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94536': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94539': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94402': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94404': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94403': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94538': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94560': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94065': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94063': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94027': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94002': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94070': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '95134': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '95002': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94062': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94089': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94301': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94025': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94303': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '95035': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '95140': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94061': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94043': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94304': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94305': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94035': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94306': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94028': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94040': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94022': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94085': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94086': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94024': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}, '94087': {'python': 1, 'java': 1, 'Machine': 1, 'learning': 2, 'selenium': 1, 'react': 2, 'plan': 1, 'functional': 1, 'mobile': 2, 'android': 1, 'ios': 2, 'black': 1, 'google': 2, 'network': 2, 'ci/cd': 1, 'swift': 1, 'objective-c': 1, 'go': 1, 'appium': 1, 'ui': 1, 'database': 1, 'healthcare': 1, 'Mathematics': 1}}}}}
threshold_percent = 3.0
unpack_and_graph(data, threshold_percent)
# Out:
#                                                     demand_percent
# software quality assurance engineer in San Fran...
# ios                                                       6.896552
# google                                                    6.896552
# network                                                   6.896552
# learning                                                  6.896552
# mobile                                                    6.896552
# react                                                     6.896552
# black                                                     3.448276
# plan                                                      3.448276
# database                                                  3.448276
# android                                                   3.448276
# Mathematics                                               3.448276
# Machine                                                   3.448276
# ...
